# %% [markdown]
# # 3.6 动手：重新发明一台可学习世界模型
#
# 姓名：
#
# 本模板只规定证据顺序，不规定你的模型结构。先阅读 `docs/projects/03-learnable-world.md`。

# %% [markdown]
# ## 1. 问题与接口
#
# 用自己的例子说明：当前观察为什么不够？模型读入什么、交出什么？不要复制论文图。

# %%
# TODO: 定义环境、状态、动作和一个最简单基线
assert True

# %% [markdown]
# ## 2. 数据卡
#
# 写明 episode、时间对齐、split、seed 与生成命令。

# %%
# TODO: 展示三个 transition，并检查 T 个观察对应 T-1 个动作
assert True

# %% [markdown]
# ## 3. 学习动态
#
# 实现从经历学习的模型，并与人写规则或复制状态比较。

# %%
# TODO: 训练或统计 learned dynamics
assert True

# %% [markdown]
# ## 4. 多步、反事实与闭环
#
# 画 horizon 曲线；固定起点替换动作；让 planner 在真实环境执行。

# %%
# TODO: 输出主指标和至少一组失败
assert True

# %% [markdown]
# ## 5. 结果没有证明什么
#
# 若观察换成图片、动作连续或未来随机，当前系统还缺什么？
