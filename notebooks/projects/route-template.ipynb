# %% [markdown]
# # 路线收尾：一台完整的小整机
#
# 路线：决策与规划 / 互动视频 / JEPA / 机器人与 VLA / 空间世界
#
# 姓名：
#
# 先阅读所选路线最后一份动手页。本模板不替代路线专属指标。

# %% [markdown]
# ## 1. 研究问题与最小基线
#
# 你的系统想修复什么失败？最便宜的替代方法是什么？

# %%
ROUTE = 'A'  # TODO
SEED = 0
assert ROUTE in 'ABCDE'

# %% [markdown]
# ## 2. 数据卡与 split
#
# 记录 artifact SHA256、episode/scene/task 边界、动作时间和控制频率。

# %%
# TODO: 载入数据并显示输入输出 shape
assert True

# %% [markdown]
# ## 3. 组件 smoke 与小批过拟合
#
# 先证明梯度、loss 与 checkpoint 路径正确。

# %%
# TODO: 最小训练
assert True

# %% [markdown]
# ## 4. 完整训练与主指标
#
# 保存曲线、配置、运行时间、显存和 checkpoint 哈希。

# %%
# TODO: 路线完整训练与验证
assert True

# %% [markdown]
# ## 5. Horizon、反事实与 OOD
#
# 固定起点换动作；改变一个训练范围之外的条件。

# %%
# TODO: 评价与失败图集
assert True

# %% [markdown]
# ## 6. 下游或闭环
#
# 模型有没有帮助真实 return、动作一致性、probe、机器人成功或空间指标？

# %% [markdown]
# ## 7. 结果边界
#
# 写清结果支持什么、没有支持什么，以及 9.4 最值得追的稳定失败。
