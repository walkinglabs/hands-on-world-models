# %% [markdown]
# # 9.4 动手：设计下一台世界模型
#
# 姓名：
#
# 从所选路线最后一份动手里的稳定失败开始，不从新架构名字开始。

# %% [markdown]
# ## 1. 可复现失败
#
# 写出条件、命令、seed 与量化证据。

# %%
# TODO: 重现基线失败至少三次
assert True

# %% [markdown]
# ## 2. 两种竞争解释
#
# 解释 A：
#
# 解释 B：
#
# 哪项实验能区分它们？

# %% [markdown]
# ## 3. 最小改动与可证伪预测
#
# 只改一个主要因素。提前写下什么结果会证明你的办法没有用。

# %%
# TODO: 实现最小改动
assert True

# %% [markdown]
# ## 4. 公平对照
#
# 固定 split、seed、updates 或计算预算，报告平均、波动与资源差异。

# %%
# TODO: 运行 baseline 与 proposed
assert True

# %% [markdown]
# ## 5. 结论
#
# 结果支持了什么？没有支持什么？下一件最值得收集的证据是什么？

# %% [markdown]
# ## 6. 运行证据与参考文献
#
# 附 manifest、checkpoint SHA256 和 3–5 篇直接相关论文。
